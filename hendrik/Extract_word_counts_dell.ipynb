# %%
import pandas as pd
import re
from bs4 import BeautifulSoup as BS
import glob
import codecs

# %%
listoffiles=glob.glob('../../cdips_dell/test/*.html')

# %%
file=open(listoffiles[0],'r',encoding='utf-8').read()

# %%
file_parse=BS(file,"lxml")
letters_file=re.sub("[^a-zA-Z]"," ",file_parse.get_text())
print (letters_file)
# Out:
#     Inspiron         Series  Advanced  Details   Dell                                                                      Dell   window Dell                        Dell Metrics   Dell Metrics                        Dell Metrics sc                         country   us                       language   en                       segment   bsd                       customerset                            cms   nextgen                       pagename   us en bsd     x inspiron         laptop                       delladvantagelogin   False                       dfsauthstate   cold no dpa no da                        flash   false   productvariant   inspiron         laptop                                     if typeof Dell Metrics sc flash      undefined      DELL com Utils hasFlash                                          Dell Metrics sc flash    false                                       mboxCreate  enus ng   profile r us   profile c us   profile l en   profile s bsd   profile cs      prof
# ...

# %%
file_lower_case=letters_file.lower()
words=file_lower_case.split()

# %%
# Out:
# ['inspiron',
#  'series',
#  'advanced',
#  'details',
#  'dell',
#  'dell',
#  'window',
#  'dell',
#  'dell',
#  'metrics',
#  'dell',
#  'metrics',
#  'dell',
#  'metrics',
#  'sc',
#  'country',
#  'us',
#  'language',
#  'en',
#  'segment',
#  'bsd',
#  'customerset',
#  'cms',
#  'nextgen',
#  'pagename',
#  'us',
#  'en',
#  'bsd',
#  'x',
#  'inspiron',
#  'laptop',
#  'delladvantagelogin',
#  'false',
#  'dfsauthstate',
#  'cold',
#  'no',
#  'dpa',
#  'no',
#  'da',
#  'flash',
#  'false',
#  'productvariant',
#  'inspiron',
#  'laptop',
#  'if',
#  'typeof',
#  'dell',
#  'metrics',
#  'sc',
#  'flash',
#  'undefined',
#  'dell',
#  'com',
#  'utils',
#  'hasflash',
#  'dell',
#  'metrics',
#  'sc',
#  'flash',
#  'false',
#  'mboxcreate',
#  'enus',
#  'ng',
#  'profile',
#  'r',
#  'us',
#  'profile',
#  'c',
#  'us',
#  'profile',
#  'l',
#  'en',
#  'profile',
#  's',
#  'bsd',
#  'profile',
#  'cs',
#  'profile',
#  'pn',
#  'us',
#  'en',
#  'bsd',
#  'x',
# ...
